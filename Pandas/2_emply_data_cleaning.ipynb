# %%
import pandas as pd

# %%
employe_data_csv = './DataFiles/employe_data.csv'
data = pd.read_csv(employe_data_csv)

df = pd.DataFrame(data)

# %%
df.head()
# Out:
#             id first_name  last_name                     email  gender  \
# 0  52-822-0508      Izaak        NaN  istag0@deliciousdays.com    Male
# 1  78-152-5454    Victoir       Beek        vbeek1@smugmug.com     NaN
# 2  88-827-4028    Roobbie  Van Halle                       NaN     NaN
# 3  27-858-0091     Sibeal        NaN           slaxon3@loc.gov  Female
# 4  88-272-4425   Koenraad  Brilleman    kbrilleman4@tumblr.com     NaN
#
#        adress previous_Company pay_per_hour
# 0  12th Floor            Oyoba       $46.12
# 1         NaN          Buzzdog      $101.63
# 2         NaN       Thoughtmix       $21.14
# 3    Room 405           Skimia      $111.64
# 4         NaN           Twinte      $145.04

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1000 non-null   object
#  1   first_name        939 non-null    object
#  2   last_name         829 non-null    object
#  3   email             846 non-null    object
#  4   gender            779 non-null    object
#  5   adress            545 non-null    object
#  6   previous_Company  874 non-null    object
#  7   pay_per_hour      937 non-null    object
# dtypes: object(8)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#                  id first_name last_name                     email  gender  \
# count          1000        939       829                       846     779
# unique         1000        890       824                       846       8
# top     52-822-0508      Ronny   Kinlock  istag0@deliciousdays.com  Female
# freq              1          3         2                         1     364
#
#             adress previous_Company pay_per_hour
# count          545              874          937
# unique         423              340          912
# top     19th Floor            Voomm       $50.28
# freq            12                9            2

# %%
df['first_name']
# Out:
# 0         Izaak
# 1       Victoir
# 2       Roobbie
# 3        Sibeal
# 4      Koenraad
#          ...
# 995       Neala
# 996     Wyndham
# 997       Nerty
# 998       Torry
# 999      Maggee
# Name: first_name, Length: 1000, dtype: object

# %%
df.iloc[0]
# Out:
# id                               52-822-0508
# first_name                             Izaak
# last_name                                NaN
# email               istag0@deliciousdays.com
# gender                                  Male
# adress                            12th Floor
# previous_Company                       Oyoba
# pay_per_hour                          $46.12
# Name: 0, dtype: object

# %%
df.iloc[0:20]
# Out:
#              id first_name  last_name                        email  \
# 0   52-822-0508      Izaak        NaN     istag0@deliciousdays.com
# 1   78-152-5454    Victoir       Beek           vbeek1@smugmug.com
# 2   88-827-4028    Roobbie  Van Halle                          NaN
# 3   27-858-0091     Sibeal        NaN              slaxon3@loc.gov
# 4   88-272-4425   Koenraad  Brilleman       kbrilleman4@tumblr.com
# 5   57-449-3992   Perceval     Norris                          NaN
# 6   50-121-2150    Luciano    Clayton             lclayton6@hp.com
# 7   63-487-4186     Felipa    Steward          fsteward7@google.it
# 8   01-794-8290      Jonah        NaN   jgoldberg8@dagondesign.com
# 9   63-316-4239     Carlee     Oakman                          NaN
# 10  32-099-5331    Barnett     Barukh            bbarukha@dell.com
# 11  94-920-9448     Josias  Terbrugge          jterbruggeb@unc.edu
# 12  41-089-3326    Gustavo        NaN                          NaN
# ...

# %%
name = df.set_index('first_name')
name.loc['Whit']
# Out:
# id                  40-072-6974
# last_name                  Pack
# email                       NaN
# gender                     Male
# adress                  Apt 801
# previous_Company          Zoovu
# pay_per_hour             $20.99
# Name: Whit, dtype: object

# %%
df['pay_per_hour'] = df['pay_per_hour'].fillna('$0')
df['pay_per_hour'] = df['pay_per_hour'].replace({'\$':''},regex=True).astype(float).astype(int)

# %%
df.head()
# Out:
#             id first_name  last_name                     email  gender  \
# 0  52-822-0508      Izaak        NaN  istag0@deliciousdays.com    Male
# 1  78-152-5454    Victoir       Beek        vbeek1@smugmug.com     NaN
# 2  88-827-4028    Roobbie  Van Halle                       NaN     NaN
# 3  27-858-0091     Sibeal        NaN           slaxon3@loc.gov  Female
# 4  88-272-4425   Koenraad  Brilleman    kbrilleman4@tumblr.com     NaN
#
#        adress previous_Company  pay_per_hour
# 0  12th Floor            Oyoba            46
# 1         NaN          Buzzdog           101
# 2         NaN       Thoughtmix            21
# 3    Room 405           Skimia           111
# 4         NaN           Twinte           145

# %%
filter_df = df[df['pay_per_hour'] >40]
below_forty = df[df['pay_per_hour'] <40]
below_forty.head()
# Out:
#              id first_name  last_name email  gender        adress  \
# 2   88-827-4028    Roobbie  Van Halle   NaN     NaN           NaN
# 9   63-316-4239     Carlee     Oakman   NaN  Female  PO Box 54634
# 12  41-089-3326    Gustavo        NaN   NaN    Male           NaN
# 16  40-072-6974       Whit       Pack   NaN    Male       Apt 801
# 22  99-925-4113      Lindy    Jacobsz   NaN     NaN           NaN
#
#    previous_Company  pay_per_hour
# 2        Thoughtmix            21
# 9             Miboo             0
# 12           Skinix            34
# 16            Zoovu            20
# 22           Skibox            33

# %%
filter_df.head()
# Out:
#             id first_name  last_name                     email  gender  \
# 0  52-822-0508      Izaak        NaN  istag0@deliciousdays.com    Male
# 1  78-152-5454    Victoir       Beek        vbeek1@smugmug.com     NaN
# 3  27-858-0091     Sibeal        NaN           slaxon3@loc.gov  Female
# 4  88-272-4425   Koenraad  Brilleman    kbrilleman4@tumblr.com     NaN
# 5  57-449-3992   Perceval     Norris                       NaN    Male
#
#        adress previous_Company  pay_per_hour
# 0  12th Floor            Oyoba            46
# 1         NaN          Buzzdog           101
# 3    Room 405           Skimia           111
# 4         NaN           Twinte           145
# 5         NaN             Vitz           105

# %%
# Filter rows where Age > 25 AND City is Chicago
new_df = df[(df['email'].isna()) & (df['gender'] == 'Female')]

# %%
new_df.head()
# Out:
#              id first_name last_name email  gender        adress  \
# 9   63-316-4239     Carlee    Oakman   NaN  Female  PO Box 54634
# 33  56-299-4113        Una       NaN   NaN  Female           NaN
# 47  24-389-3418  Cassondra   Brettor   NaN  Female    15th Floor
# 56  71-783-8484     Karlyn  Bresland   NaN  Female           NaN
# 72  77-961-7769      Robyn   Kinlock   NaN  Female     6th Floor
#
#    previous_Company  pay_per_hour
# 9             Miboo             0
# 33              NaN            81
# 47             Lajo            67
# 56           Talane            22
# 72          Gabtype           130

# %%
name_filter = df[df['first_name'].str.contains('ma',case = False,na=False)]

# %%
name_filter.head()
# Out:
#               id first_name  last_name                     email       gender  \
# 42   00-950-4738      Marlo     Rettie       mrettie16@lycos.com       Female
# 77   19-021-2325     Marris  Pickworth  mpickworth25@godaddy.com   Non-binary
# 90   36-139-8405    Mallory   Plaskitt   mplaskitt2i@tinypic.com          NaN
# 143  22-434-6156   Marthena    Kiledal      mkiledal3z@wiley.com  Genderfluid
# 165  00-143-2791     Norman  Skeldinge     nskeldinge4l@yelp.com         Male
#
#            adress previous_Company  pay_per_hour
# 42            NaN             Kare            62
# 77       Room 241         Riffpath            20
# 90            NaN        Brightdog            46
# 143     Room 1653             Mita            48
# 165  PO Box 89188            Voomm           139

# %%
# Filter rows where gender is either 'male' or 'female'

gender_df = df[df['gender'].isin(['Male','Female'])]
gender_df.head()
# Out:
#             id first_name last_name                     email  gender  \
# 0  52-822-0508      Izaak       NaN  istag0@deliciousdays.com    Male
# 3  27-858-0091     Sibeal       NaN           slaxon3@loc.gov  Female
# 5  57-449-3992   Perceval    Norris                       NaN    Male
# 6  50-121-2150    Luciano   Clayton          lclayton6@hp.com    Male
# 7  63-487-4186     Felipa   Steward       fsteward7@google.it  Female
#
#        adress previous_Company  pay_per_hour
# 0  12th Floor            Oyoba            46
# 3    Room 405           Skimia           111
# 5         NaN             Vitz           105
# 6         NaN           Skyndu           155
# 7         NaN            Quinu            86

# %%
#handeling missing data.
# droping the null values in email

new_df = gender_df[gender_df['email'].notna()]

# %%
new_df.head()
# Out:
#             id first_name last_name                       email  gender  \
# 0  52-822-0508      Izaak       NaN    istag0@deliciousdays.com    Male
# 3  27-858-0091     Sibeal       NaN             slaxon3@loc.gov  Female
# 6  50-121-2150    Luciano   Clayton            lclayton6@hp.com    Male
# 7  63-487-4186     Felipa   Steward         fsteward7@google.it  Female
# 8  01-794-8290      Jonah       NaN  jgoldberg8@dagondesign.com    Male
#
#        adress previous_Company  pay_per_hour
# 0  12th Floor            Oyoba            46
# 3    Room 405           Skimia           111
# 6         NaN           Skyndu           155
# 7         NaN            Quinu            86
# 8         NaN           Meezzy            91

# %%
#drop null values in pay_per_hour in df

df['pay_per_hour'].dropna(inplace=True)

# %%
df.head()
# Out:
#             id first_name  last_name                     email  gender  \
# 0  52-822-0508      Izaak    unknown  istag0@deliciousdays.com    Male
# 1  78-152-5454    Victoir       Beek        vbeek1@smugmug.com     NaN
# 2  88-827-4028    Roobbie  Van Halle                       NaN     NaN
# 3  27-858-0091     Sibeal    unknown           slaxon3@loc.gov  Female
# 4  88-272-4425   Koenraad  Brilleman    kbrilleman4@tumblr.com     NaN
#
#        adress previous_Company  pay_per_hour
# 0  12th Floor            Oyoba            46
# 1         NaN          Buzzdog           101
# 2         NaN       Thoughtmix            21
# 3    Room 405           Skimia           111
# 4         NaN           Twinte           145

# %%
# filling last_name with "unknown"
df['last_name'].fillna('unknown',inplace=True)

# %%
df.head()
# Out:
#             id first_name  last_name                     email  gender  \
# 0  52-822-0508      Izaak    unknown  istag0@deliciousdays.com    Male
# 1  78-152-5454    Victoir       Beek        vbeek1@smugmug.com     NaN
# 2  88-827-4028    Roobbie  Van Halle                       NaN     NaN
# 3  27-858-0091     Sibeal    unknown           slaxon3@loc.gov  Female
# 4  88-272-4425   Koenraad  Brilleman    kbrilleman4@tumblr.com     NaN
#
#        adress previous_Company  pay_per_hour
# 0  12th Floor            Oyoba            46
# 1         NaN          Buzzdog           101
# 2         NaN       Thoughtmix            21
# 3    Room 405           Skimia           111
# 4         NaN           Twinte           145

# %%
#rename colums  

df.rename(columns={'pay_per_hour':'salary'},inplace=True)

# %%
df.head()
# Out:
#             id first_name  last_name                     email  gender  \
# 0  52-822-0508      Izaak    unknown  istag0@deliciousdays.com    Male
# 1  78-152-5454    Victoir       Beek        vbeek1@smugmug.com     NaN
# 2  88-827-4028    Roobbie  Van Halle                       NaN     NaN
# 3  27-858-0091     Sibeal    unknown           slaxon3@loc.gov  Female
# 4  88-272-4425   Koenraad  Brilleman    kbrilleman4@tumblr.com     NaN
#
#        adress previous_Company  salary
# 0  12th Floor            Oyoba      46
# 1         NaN          Buzzdog     101
# 2         NaN       Thoughtmix      21
# 3    Room 405           Skimia     111
# 4         NaN           Twinte     145

# %%
df.replace({'Male':'M'},inplace=True)
df.head()
# Out:
#             id first_name  last_name                     email  gender  \
# 0  52-822-0508      Izaak    unknown  istag0@deliciousdays.com       M
# 1  78-152-5454    Victoir       Beek        vbeek1@smugmug.com     NaN
# 2  88-827-4028    Roobbie  Van Halle                       NaN     NaN
# 3  27-858-0091     Sibeal    unknown           slaxon3@loc.gov  Female
# 4  88-272-4425   Koenraad  Brilleman    kbrilleman4@tumblr.com     NaN
#
#        adress previous_Company  salary
# 0  12th Floor            Oyoba      46
# 1         NaN          Buzzdog     101
# 2         NaN       Thoughtmix      21
# 3    Room 405           Skimia     111
# 4         NaN           Twinte     145
